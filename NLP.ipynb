# %%
corpus=""" Hello Welcome to the world of Natural Language Processing. This is a sample corpus for testing purposes. We will be performing various NLP tasks on this corpus. Let's explore the world of NLP together! """

# %%
print(corpus)
# Out:
#  Hello Welcome to the world of Natural Language Processing. This is a sample corpus for testing purposes. We will be performing various NLP tasks on this corpus. Let's explore the world of NLP together!

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\akshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\akshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome to the world of Natural Language Processing.
# This is a sample corpus for testing purposes.
# We will be performing various NLP tasks on this corpus.
# Let's explore the world of NLP together!

# %%
# Tokenization is the process of breaking down a text into smaller units called tokens. In this case, we are using sentence tokenization, which breaks the text into individual sentences. Each sentence is treated as a separate document for further processing in NLP tasks.
# Paragraph ---> words
# Sentence ---> words

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Natural',
#  'Language',
#  'Processing',
#  '.',
#  'This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'for',
#  'testing',
#  'purposes',
#  '.',
#  'We',
#  'will',
#  'be',
#  'performing',
#  'various',
#  'NLP',
#  'tasks',
#  'on',
#  'this',
#  'corpus',
#  '.',
#  'Let',
#  "'s",
#  'explore',
#  'the',
#  'world',
#  'of',
#  'NLP',
#  'together',
#  '!']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Natural',
#  'Language',
#  'Processing.',
#  'This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'for',
#  'testing',
#  'purposes.',
#  'We',
#  'will',
#  'be',
#  'performing',
#  'various',
#  'NLP',
#  'tasks',
#  'on',
#  'this',
#  'corpus.',
#  'Let',
#  "'s",
#  'explore',
#  'the',
#  'world',
#  'of',
#  'NLP',
#  'together',
#  '!']

# %%
# Stemming is the process of reducing a word to its base or root form. It helps in normalizing the text and reducing the vocabulary size. For example, the words "running", "runner", and "ran" can all be reduced to the stem "run". This is useful in NLP tasks such as information retrieval, text classification, and sentiment analysis, where we want to treat different forms of a word as the same entity.
# Stemming is important in NLU & NLP.

# %%
#eating, eat, eaten---> eat
#going, gone, goes---> go
words=['eating','eats','eaten','writing','writes','programming','programs','history','finally','finalized']

# %%
# Porter Stemmer
from nltk.stem import PorterStemmer
stemming=PorterStemmer()
for word in words:
    print(word, "---->", stemming.stem(word))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eaten
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program
# history ----> histori
# finally ----> final
# finalized ----> final

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('standing')
# Out:
# 'stand'

# %%
#Regexp Stemmer
from nltk.stem import RegexpStemmer
regexp_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
regexp_stemmer.stem('eating')
# Out:
# 'eat'

# %%
regexp_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %%
# Snowball Stemmer
from nltk.stem import SnowballStemmer
snowball_stemmer=SnowballStemmer('english')
for word in words:
    print(word, "---->", snowball_stemmer.stem(word))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eaten
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program
# history ----> histori
# finally ----> final
# finalized ----> final

# %%
# lemmatization
# lemmatization is the technoque of reducing a word to its base or root form, known as the lemma. Unlike stemming, which simply chops off prefixes and suffixes, lemmatization considers the context and meaning of the word to determine its correct base form. For example, the words "running", "runner", and "ran" would all be reduced to the lemma "run". Lemmatization is important in NLP tasks such as information retrieval, text classification, and sentiment analysis, where we want to treat different forms of a word as the same entity while preserving their meaning.
# word lemmatizer
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\akshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer.lemmatize('going', pos='v')
# Out:
# 'go'

# %%
words=['eating','eats','eaten','writing','writes','programming','programs','history','finally','finalized']
for word in words:
    print(word, "---->", lemmatizer.lemmatize(word, pos='v'))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eat
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program
# history ----> history
# finally ----> finally
# finalized ----> finalize

# %%
lemmatizer.lemmatize('fairly', pos='v'),lemmatizer.lemmatize('sportingly',pos='v')
# Out:
# ('fairly', 'sportingly')

# %%
# stemming
words=['random','randomly','randomness','randomize','randomization']
from nltk.stem import PorterStemmer
stemming=PorterStemmer()
print("Porter Stemmer:")
for word in words:
    print(word, "---->", stemming.stem(word))
print("\nRegexp Stemmer:")
from nltk.stem import RegexpStemmer
regexp_stemmer=RegexpStemmer('ing$|ly$|ness$|ize$|ation$', min=4)
for word in words:
    print(word, "---->", regexp_stemmer.stem(word))
print("\nSnowball Stemmer:")
from nltk.stem import SnowballStemmer
snowball_stemmer=SnowballStemmer('english')
for word in words:
    print(word, "---->", snowball_stemmer.stem(word))
# Out:
# Porter Stemmer:
# random ----> random
# randomly ----> randomli
# randomness ----> random
# randomize ----> random
# randomization ----> random
#
# Regexp Stemmer:
# random ----> random
# randomly ----> random
# randomness ----> random
# randomize ----> random
# randomization ----> randomiz
#
# Snowball Stemmer:
# random ----> random
# randomly ----> random
# randomness ----> random
# randomize ----> random
# randomization ----> random

# %%
# lemmatization
words=['random','randomly','randomness','randomize','randomization']
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
print("Word Lemmatizer:")
for word in words:
    print(word, "---->", lemmatizer.lemmatize(word, pos='v'))
# Out:
# Word Lemmatizer:
# random ----> random
# randomly ----> randomly
# randomness ----> randomness
# randomize ----> randomize
# randomization ----> randomization

# %%
lemmatizer.lemmatize('better', pos='v')
# Out:
# 'better'

# %%
stemming.stem('better')
# Out:
# 'better'

# %%
# The difference between stemming and lemmatization is that
#  stemming simply chops off prefixes and suffixes to reduce a word to its base form
#  while lemmatization considers the context and meaning of the word to determine its correct base form. 
# Stemming may produce non-words or incorrect base forms,
#  while lemmatization produces valid words that are the base form of the original word.

# %%
## Speech Of DR APJ Abdul Kalam

paragraph = """I have three visions for India. In 3000 years of our history, people from all over 

               the world have come and invaded us, captured our lands, conquered our minds. 

               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,

               the French, the Dutch, all of them came and looted us, took over what was ours. 

               Yet we have not done this to any other nation. We have not conquered anyone. 

               We have not grabbed their land, their culture, 

               their history and tried to enforce our way of life on them. 

               Why? Because we respect the freedom of others.That is why my 

               first vision is that of freedom. I believe that India got its first vision of 

               this in 1857, when we started the War of Independence. It is this freedom that

               we must protect and nurture and build on. If we are not free, no one will respect us.

               My second vision for India’s development. For fifty years we have been a developing nation.

               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world

               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.

               Our achievements are being globally recognised today. Yet we lack the self-confidence to

               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?

               I have a third vision. India must stand up to the world. Because I believe that unless India 

               stands up to the world, no one will respect us. Only strength respects strength. We must be 

               strong not only as a military power but also as an economic power. Both must go hand-in-hand. 

               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of 

               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.

               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life. 

               I see four milestones in my career"""
sentences=sent_tokenize(paragraph)
for sentence in sentences:
    print(sentence)
# Out:
# I have three visions for India.
# In 3000 years of our history, people from all over
#
#                the world have come and invaded us, captured our lands, conquered our minds.
# From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
#
#                the French, the Dutch, all of them came and looted us, took over what was ours.
# Yet we have not done this to any other nation.
# We have not conquered anyone.
# We have not grabbed their land, their culture,
#
#                their history and tried to enforce our way of life on them.
# Why?
# Because we respect the freedom of others.That is why my
#
#                first vision is that of freedom.
# I believe that India got its first vision of
#
#                this in 1857, when we started the War of Independence.
# It is this freedom that
#
#                we must protect and nurture and build on.
# If we are not free, no one will respect us.
# My second vision for India’s development.
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\akshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
# Apply stopwords and filter and then apply stemming.
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[stemmer.stem(word)for word in words if word not in stopwords.words('english')]
    sentences[i]=' '.join(words)
for sentence in sentences:
    print(sentence)
# Out:
# i three vision india .
# in 3000 year histori , peopl world come invad us , captur land , conquer mind .
# from alexand onward , greek , turk , mogul , portugues , british , french , dutch , came loot us , took .
# yet done nation .
# we conquer anyon .
# we grab land , cultur , histori tri enforc way life .
# whi ?
# becaus respect freedom others.that first vision freedom .
# i believ india got first vision 1857 , start war independ .
# it freedom must protect nurtur build .
# if free , one respect us .
# my second vision india ’ develop .
# for fifti year develop nation .
# it time see develop nation .
# we among top 5 nation world term gdp .
# we 10 percent growth rate area .
# our poverti level fall .
# our achiev global recognis today .
# yet lack self-confid see develop nation , self-reli self-assur .
# isn ’ incorrect ?
# i third vision .
# india must stand world .
# becaus i believ unless india stand world , one respect us .
# onli strength respect strength .
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
# Apply stopwords and filter and then apply stemming.
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[lemmatizer.lemmatize(word)for word in words if word not in stopwords.words('english')]
    sentences[i]=' '.join(words)

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\akshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in stop_words]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('three', 'CD'), ('vision', 'NN'), ('india', 'NN'), ('.', '.')]
# [('3000', 'CD'), ('year', 'NN'), ('histori', 'NN'), (',', ','), ('peopl', 'JJ'), ('world', 'NN'), ('come', 'VBP'), ('invad', 'NN'), ('u', 'NN'), (',', ','), ('captur', 'NN'), ('land', 'NN'), (',', ','), ('conquer', 'NN'), ('mind', 'NN'), ('.', '.')]
# [('alexand', 'RB'), ('onward', 'RB'), (',', ','), ('greek', 'JJ'), (',', ','), ('turk', 'NN'), (',', ','), ('mogul', 'NN'), (',', ','), ('portugues', 'NNS'), (',', ','), ('british', 'JJ'), (',', ','), ('french', 'JJ'), (',', ','), ('dutch', 'VB'), (',', ','), ('came', 'VBD'), ('loot', 'JJ'), ('u', 'NN'), (',', ','), ('took', 'VBD'), ('.', '.')]
# [('yet', 'RB'), ('done', 'VBN'), ('nation', 'NN'), ('.', '.')]
# [('conquer', 'NN'), ('anyon', 'NN'), ('.', '.')]
# [('grab', 'NN'), ('land', 'NN'), (',', ','), ('cultur', 'NN'), (',', ','), ('histori', 'JJ'), ('tri', 'NN'), ('enforc', 'NN'), ('way', 'NN'), ('life', 'NN'), ('.', '.')]
# [('whi', 'NN'), ('?', '.')]
# ...
